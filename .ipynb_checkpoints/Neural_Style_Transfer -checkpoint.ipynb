# %% [markdown]
# ### Import librairies

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import math
import time

# %%
from tensorflow.keras.applications.vgg19 import VGG19, preprocess_input
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from tensorflow.keras.models import Model

# %% [markdown]
# ### Load images

# %%
content_path = r"C:\Users\User\Desktop\Internship\Neural Style Transfer\Content image.jpg"
style_path = r"C:\Users\User\Desktop\Internship\Neural Style Transfer\Style image.jpg"

# %% [markdown]
# ### Load and process image

# %%
def load_and_process_image(image_path):
    img = load_img(image_path)
    # convert image to array
    img = img_to_array(img)
    img = preprocess_input(img)
    img = np.expand_dims(img, axis=0)
    return img

# %%
def deprocess(img):
    # perform the inverse of the pre processing step
    img[:, :, 0] += 103.939
    img[:, :, 1] += 116.779
    img[:, :, 2] += 123.68
    # convert RGB to BGR
    img = img[:, :, ::-1]
 
    img = np.clip(img, 0, 255).astype('uint8')
    return img
 
 
def display_image(image):
    # remove one dimension if image has 4 dimension
    if len(image.shape) == 4:
        img = np.squeeze(image, axis=0)
 
    img = deprocess(img)
 
    plt.grid(False)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(img)
    return

# %% [markdown]
# ### Load content image

# %%
content_img = load_and_process_image(content_path)
display_image(content_img)

# %% [markdown]
# ### Load style image

# %%
style_img = load_and_process_image(style_path)
display_image(style_img)

# %% [markdown]
# ### Download the VGG model and initialise it

# %%
model = VGG19(
    include_top=False,
    weights='imagenet'
)

model.trainable = False
 
model.summary()
# Out:
# Model: "vgg19"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, None, None, 3)]   0
#
#  block1_conv1 (Conv2D)       (None, None, None, 64)    1792
#
#  block1_conv2 (Conv2D)       (None, None, None, 64)    36928
#
#  block1_pool (MaxPooling2D)  (None, None, None, 64)    0
#
#  block2_conv1 (Conv2D)       (None, None, None, 128)   73856
#
#  block2_conv2 (Conv2D)       (None, None, None, 128)   147584
#
#  block2_pool (MaxPooling2D)  (None, None, None, 128)   0
#
#  block3_conv1 (Conv2D)       (None, None, None, 256)   295168
#
#  block3_conv2 (Conv2D)       (None, None, None, 256)   590080
#
#  block3_conv3 (Conv2D)       (None, None, None, 256)   590080
#
#  block3_conv4 (Conv2D)       (None, None, None, 256)   590080
#
#  block3_pool (MaxPooling2D)  (None, None, None, 256)   0
#
#  block4_conv1 (Conv2D)       (None, None, None, 512)   1180160
#
#  block4_conv2 (Conv2D)       (None, None, None, 512)   2359808
#
#  block4_conv3 (Conv2D)       (None, None, None, 512)   2359808
#
#  block4_conv4 (Conv2D)       (None, None, None, 512)   2359808
#
#  block4_pool (MaxPooling2D)  (None, None, None, 512)   0
#
#  block5_conv1 (Conv2D)       (None, None, None, 512)   2359808
#
#  block5_conv2 (Conv2D)       (None, None, None, 512)   2359808
#
#  block5_conv3 (Conv2D)       (None, None, None, 512)   2359808
#
#  block5_conv4 (Conv2D)       (None, None, None, 512)   2359808
#
#  block5_pool (MaxPooling2D)  (None, None, None, 512)   0
#
# =================================================================
# Total params: 20024384 (76.39 MB)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 20024384 (76.39 MB)
# _________________________________________________________________

# %%
# define content model
content_layer = 'block5_conv2'
content_model = Model(
    inputs=model.input,
    outputs=model.get_layer(content_layer).output
)
content_model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, None, None, 3)]   0
#
#  block1_conv1 (Conv2D)       (None, None, None, 64)    1792
#
#  block1_conv2 (Conv2D)       (None, None, None, 64)    36928
#
#  block1_pool (MaxPooling2D)  (None, None, None, 64)    0
#
#  block2_conv1 (Conv2D)       (None, None, None, 128)   73856
#
#  block2_conv2 (Conv2D)       (None, None, None, 128)   147584
#
#  block2_pool (MaxPooling2D)  (None, None, None, 128)   0
#
#  block3_conv1 (Conv2D)       (None, None, None, 256)   295168
#
#  block3_conv2 (Conv2D)       (None, None, None, 256)   590080
#
#  block3_conv3 (Conv2D)       (None, None, None, 256)   590080
#
#  block3_conv4 (Conv2D)       (None, None, None, 256)   590080
#
#  block3_pool (MaxPooling2D)  (None, None, None, 256)   0
#
#  block4_conv1 (Conv2D)       (None, None, None, 512)   1180160
#
#  block4_conv2 (Conv2D)       (None, None, None, 512)   2359808
#
#  block4_conv3 (Conv2D)       (None, None, None, 512)   2359808
#
#  block4_conv4 (Conv2D)       (None, None, None, 512)   2359808
#
#  block4_pool (MaxPooling2D)  (None, None, None, 512)   0
#
#  block5_conv1 (Conv2D)       (None, None, None, 512)   2359808
#
#  block5_conv2 (Conv2D)       (None, None, None, 512)   2359808
#
# =================================================================
# Total params: 15304768 (58.38 MB)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 15304768 (58.38 MB)
# _________________________________________________________________

# %%
# define style model
style_layers = [
    'block1_conv1',
    'block3_conv1',
    'block5_conv1'
]
style_models = [Model(inputs=model.input,
                      outputs=model.get_layer(layer).output) for layer in style_layers]

# %%
# Content loss
def content_loss(content, generated):
    a_C = content_model(content)
    a_G = content_model(generated)  # Add this line to compute a_G
    loss = tf.reduce_mean(tf.square(a_C - a_G))
    return loss

# %%
# gram matrix
def gram_matrix(A):
    channels = int(A.shape[-1])
    a = tf.reshape(A, [-1, channels])
    n = tf.shape(a)[0]
    gram = tf.matmul(a, a, transpose_a=True)
    return gram / tf.cast(n, tf.float32)
 
 
weight_of_layer = 1. / len(style_models)

# %%
#style loss
def style_cost(style, generated):
    J_style = 0
 
    for style_model in style_models:
        a_S = style_model(style)
        a_G = style_model(generated)
        GS = gram_matrix(a_S)
        GG = gram_matrix(a_G)
        content_cost = tf.reduce_mean(tf.square(GS - GG))
        J_style += content_cost * weight_of_layer
 
    return J_style

# %%
# training function
generated_images = []
 
 
def training_loop(content_path, style_path, iterations=80, a=10, b=1000):
    # load content and style images from their respective paths
    content = load_and_process_image(content_path)
    style = load_and_process_image(style_path)
    generated = tf.Variable(content, dtype=tf.float32)

    opt = tf.keras.optimizers.Adam(learning_rate=7)

    best_cost = math.inf
    best_image = None
    for i in range(iterations):
        start_time_cpu = time.process_time()
        start_time_wall = time.time()
        with tf.GradientTape() as tape:
            J_content = content_loss(content, generated)  # Corrected line
            J_style = style_cost(style, generated)
            J_total = a * J_content + b * J_style

        grads = tape.gradient(J_total, generated)
        opt.apply_gradients([(grads, generated)])

        end_time_cpu = time.process_time()
        end_time_wall = time.time()
        cpu_time = end_time_cpu - start_time_cpu
        wall_time = end_time_wall - start_time_wall

        if J_total < best_cost:
            best_cost = J_total
            best_image = generated.numpy()

        print("CPU times: user {} µs, sys: {} ns, total: {} µs".format(
            int(cpu_time * 1e6),
            int((end_time_cpu - start_time_cpu) * 1e9),
            int((end_time_cpu - start_time_cpu + 1e-6) * 1e6))
        )

        print("Wall time: {:.2f} µs".format(wall_time * 1e6))
        print("Iteration :{}".format(i))
        print('Total Loss {:e}.'.format(J_total))
        generated_images.append(generated.numpy())

    return best_image

# %%
final_img = training_loop(content_path, style_path)
# Out:
# CPU times: user 25203125 µs, sys: 25203125000 ns, total: 25203126 µs
# Wall time: 12468097.21 µs
# Iteration :0
# Total Loss 4.116801e+11.
# CPU times: user 24828125 µs, sys: 24828125000 ns, total: 24828126 µs
# Wall time: 12362885.00 µs
# Iteration :1
# Total Loss 1.707247e+11.
# CPU times: user 23953125 µs, sys: 23953125000 ns, total: 23953126 µs
# Wall time: 12382922.17 µs
# Iteration :2
# Total Loss 1.028555e+11.
# CPU times: user 25593750 µs, sys: 25593750000 ns, total: 25593751 µs
# Wall time: 12376428.60 µs
# Iteration :3
# Total Loss 8.675486e+10.
# CPU times: user 24234375 µs, sys: 24234375000 ns, total: 24234376 µs
# Wall time: 12439209.46 µs
# Iteration :4
# Total Loss 7.574516e+10.
# CPU times: user 26062500 µs, sys: 26062500000 ns, total: 26062501 µs
# Wall time: 12672814.61 µs
# Iteration :5
# Total Loss 6.654393e+10.
# CPU times: user 24718750 µs, sys: 24718750000 ns, total: 24718751 µs
# Wall time: 12232128.14 µs
# Iteration :6
# Total Loss 5.814752e+10.
# CPU times: user 24781250 µs, sys: 24781250000 ns, total: 24781251 µs
# Wall time: 12469196.08 µs
# Iteration :7
# Total Loss 5.105557e+10.
# CPU times: user 23437500 µs, sys: 23437500000 ns, total: 23437501 µs
# Wall time: 12545604.94 µs
# Iteration :8
# Total Loss 4.548714e+10.
# CPU times: user 24687500 µs, sys: 24687500000 ns, total: 24687501 µs
# Wall time: 12530943.87 µs
# Iteration :9
# Total Loss 4.085356e+10.
# CPU times: user 23937500 µs, sys: 23937500000 ns, total: 23937501 µs
# Wall time: 12373408.08 µs
# Iteration :10
# Total Loss 3.660811e+10.
# CPU times: user 23328125 µs, sys: 23328125000 ns, total: 23328126 µs
# Wall time: 12297038.79 µs
# Iteration :11
# Total Loss 3.289233e+10.
# CPU times: user 23796875 µs, sys: 23796875000 ns, total: 23796876 µs
# Wall time: 12406873.70 µs
# Iteration :12
# Total Loss 2.980188e+10.
# CPU times: user 25281250 µs, sys: 25281250000 ns, total: 25281251 µs
# Wall time: 12470277.07 µs
# Iteration :13
# Total Loss 2.709994e+10.
# CPU times: user 25765625 µs, sys: 25765625000 ns, total: 25765626 µs
# Wall time: 12897680.76 µs
# Iteration :14
# Total Loss 2.462863e+10.
# CPU times: user 25281250 µs, sys: 25281250000 ns, total: 25281251 µs
# Wall time: 12726228.24 µs
# Iteration :15
# Total Loss 2.238780e+10.
# CPU times: user 25046875 µs, sys: 25046875000 ns, total: 25046876 µs
# Wall time: 12540998.94 µs
# Iteration :16
# Total Loss 2.035055e+10.
# CPU times: user 23218750 µs, sys: 23218750000 ns, total: 23218751 µs
# Wall time: 12667559.15 µs
# Iteration :17
# Total Loss 1.849843e+10.
# CPU times: user 23390625 µs, sys: 23390625000 ns, total: 23390626 µs
# Wall time: 12796261.31 µs
# Iteration :18
# Total Loss 1.687200e+10.
# CPU times: user 21765625 µs, sys: 21765625000 ns, total: 21765626 µs
# Wall time: 12895928.14 µs
# Iteration :19
# Total Loss 1.547208e+10.
# CPU times: user 24609375 µs, sys: 24609375000 ns, total: 24609376 µs
# Wall time: 12539548.40 µs
# Iteration :20
# Total Loss 1.423612e+10.
# CPU times: user 24500000 µs, sys: 24500000000 ns, total: 24500001 µs
# Wall time: 12455388.31 µs
# Iteration :21
# Total Loss 1.313241e+10.
# CPU times: user 24734375 µs, sys: 24734375000 ns, total: 24734376 µs
# Wall time: 12455485.11 µs
# Iteration :22
# Total Loss 1.213612e+10.
# CPU times: user 35156250 µs, sys: 35156250000 ns, total: 35156251 µs
# Wall time: 14777687.07 µs
# Iteration :23
# Total Loss 1.121649e+10.
# CPU times: user 32609375 µs, sys: 32609375000 ns, total: 32609375 µs
# Wall time: 11007455.59 µs
# Iteration :24
# Total Loss 1.035231e+10.
# CPU times: user 25750000 µs, sys: 25750000000 ns, total: 25750001 µs
# Wall time: 10926161.53 µs
# Iteration :25
# Total Loss 9.562352e+09.
# CPU times: user 22437500 µs, sys: 22437500000 ns, total: 22437501 µs
# Wall time: 10644615.89 µs
# Iteration :26
# Total Loss 8.855980e+09.
# CPU times: user 23781250 µs, sys: 23781250000 ns, total: 23781251 µs
# Wall time: 10808974.50 µs
# Iteration :27
# Total Loss 8.216019e+09.
# CPU times: user 23765625 µs, sys: 23765625000 ns, total: 23765626 µs
# Wall time: 11266279.70 µs
# Iteration :28
# Total Loss 7.627521e+09.
# CPU times: user 43171875 µs, sys: 43171875000 ns, total: 43171876 µs
# Wall time: 13041567.56 µs
# Iteration :29
# Total Loss 7.088275e+09.
# CPU times: user 20109375 µs, sys: 20109375000 ns, total: 20109376 µs
# Wall time: 11009302.62 µs
# Iteration :30
# Total Loss 6.592182e+09.
# CPU times: user 22359375 µs, sys: 22359375000 ns, total: 22359376 µs
# Wall time: 11182256.22 µs
# Iteration :31
# Total Loss 6.136896e+09.
# CPU times: user 25046875 µs, sys: 25046875000 ns, total: 25046876 µs
# Wall time: 11471655.37 µs
# Iteration :32
# Total Loss 5.725957e+09.
# CPU times: user 30843750 µs, sys: 30843750000 ns, total: 30843751 µs
# Wall time: 11870088.58 µs
# Iteration :33
# Total Loss 5.357325e+09.
# CPU times: user 27734375 µs, sys: 27734375000 ns, total: 27734376 µs
# Wall time: 12008208.04 µs
# Iteration :34
# Total Loss 5.021682e+09.
# CPU times: user 31093750 µs, sys: 31093750000 ns, total: 31093751 µs
# Wall time: 12180990.93 µs
# Iteration :35
# Total Loss 4.716782e+09.
# CPU times: user 38937500 µs, sys: 38937500000 ns, total: 38937501 µs
# Wall time: 12727996.59 µs
# Iteration :36
# Total Loss 4.438558e+09.
# CPU times: user 27531250 µs, sys: 27531250000 ns, total: 27531251 µs
# Wall time: 11723063.71 µs
# Iteration :37
# Total Loss 4.181071e+09.
# CPU times: user 22484375 µs, sys: 22484375000 ns, total: 22484376 µs
# Wall time: 11523364.78 µs
# Iteration :38
# Total Loss 3.943978e+09.
# CPU times: user 20312500 µs, sys: 20312500000 ns, total: 20312501 µs
# Wall time: 11615267.52 µs
# Iteration :39
# Total Loss 3.727998e+09.
# CPU times: user 19656250 µs, sys: 19656250000 ns, total: 19656251 µs
# Wall time: 11640319.59 µs
# Iteration :40
# Total Loss 3.530323e+09.
# CPU times: user 20546875 µs, sys: 20546875000 ns, total: 20546876 µs
# Wall time: 11409709.93 µs
# Iteration :41
# Total Loss 3.348783e+09.
# CPU times: user 27343750 µs, sys: 27343750000 ns, total: 27343751 µs
# Wall time: 11834474.33 µs
# Iteration :42
# Total Loss 3.183845e+09.
# CPU times: user 29921875 µs, sys: 29921875000 ns, total: 29921876 µs
# Wall time: 12831309.56 µs
# Iteration :43
# Total Loss 3.031528e+09.
# CPU times: user 26421875 µs, sys: 26421875000 ns, total: 26421876 µs
# Wall time: 10670373.20 µs
# Iteration :44
# Total Loss 2.890044e+09.
# CPU times: user 26203125 µs, sys: 26203125000 ns, total: 26203126 µs
# Wall time: 12131754.16 µs
# Iteration :45
# Total Loss 2.760674e+09.
# CPU times: user 26718750 µs, sys: 26718750000 ns, total: 26718751 µs
# Wall time: 12350438.12 µs
# Iteration :46
# Total Loss 2.642188e+09.
# CPU times: user 25703125 µs, sys: 25703125000 ns, total: 25703126 µs
# Wall time: 12303471.80 µs
# Iteration :47
# Total Loss 2.532161e+09.
# CPU times: user 26000000 µs, sys: 26000000000 ns, total: 26000001 µs
# Wall time: 12294654.37 µs
# Iteration :48
# Total Loss 2.430822e+09.
# CPU times: user 24515625 µs, sys: 24515625000 ns, total: 24515626 µs
# Wall time: 12543576.24 µs
# Iteration :49
# Total Loss 2.336799e+09.
# CPU times: user 22500000 µs, sys: 22500000000 ns, total: 22500001 µs
# Wall time: 12543706.42 µs
# Iteration :50
# Total Loss 2.248306e+09.
# CPU times: user 29578125 µs, sys: 29578125000 ns, total: 29578126 µs
# Wall time: 12933677.91 µs
# Iteration :51
# Total Loss 2.166113e+09.
# CPU times: user 31703125 µs, sys: 31703125000 ns, total: 31703126 µs
# Wall time: 12886264.80 µs
# Iteration :52
# Total Loss 2.090148e+09.
# CPU times: user 25843750 µs, sys: 25843750000 ns, total: 25843751 µs
# Wall time: 12385836.84 µs
# Iteration :53
# Total Loss 2.019365e+09.
# CPU times: user 25796875 µs, sys: 25796875000 ns, total: 25796876 µs
# Wall time: 12199847.94 µs
# Iteration :54
# Total Loss 1.953345e+09.
# CPU times: user 24734375 µs, sys: 24734375000 ns, total: 24734376 µs
# Wall time: 12184224.84 µs
# Iteration :55
# Total Loss 1.891448e+09.
# CPU times: user 24609375 µs, sys: 24609375000 ns, total: 24609376 µs
# Wall time: 12425985.34 µs
# Iteration :56
# Total Loss 1.833194e+09.
# CPU times: user 25750000 µs, sys: 25750000000 ns, total: 25750001 µs
# Wall time: 12376906.63 µs
# Iteration :57
# Total Loss 1.778885e+09.
# CPU times: user 24046875 µs, sys: 24046875000 ns, total: 24046876 µs
# Wall time: 12525882.01 µs
# Iteration :58
# Total Loss 1.727801e+09.
# CPU times: user 22453125 µs, sys: 22453125000 ns, total: 22453126 µs
# Wall time: 12448248.62 µs
# Iteration :59
# Total Loss 1.679486e+09.
# CPU times: user 21640625 µs, sys: 21640625000 ns, total: 21640626 µs
# Wall time: 12556891.68 µs
# Iteration :60
# Total Loss 1.634137e+09.
# CPU times: user 26765625 µs, sys: 26765625000 ns, total: 26765626 µs
# Wall time: 12575426.58 µs
# Iteration :61
# Total Loss 1.591294e+09.
# CPU times: user 27875000 µs, sys: 27875000000 ns, total: 27875001 µs
# Wall time: 12704784.39 µs
# Iteration :62
# Total Loss 1.550490e+09.
# CPU times: user 25828125 µs, sys: 25828125000 ns, total: 25828126 µs
# Wall time: 12515060.66 µs
# Iteration :63
# Total Loss 1.512006e+09.
# CPU times: user 24484375 µs, sys: 24484375000 ns, total: 24484376 µs
# Wall time: 12437322.62 µs
# Iteration :64
# Total Loss 1.475565e+09.
# CPU times: user 24046875 µs, sys: 24046875000 ns, total: 24046876 µs
# Wall time: 12431551.22 µs
# Iteration :65
# Total Loss 1.440977e+09.
# CPU times: user 22296875 µs, sys: 22296875000 ns, total: 22296876 µs
# Wall time: 12733012.44 µs
# Iteration :66
# Total Loss 1.408328e+09.
# CPU times: user 25500000 µs, sys: 25500000000 ns, total: 25500001 µs
# Wall time: 12779577.73 µs
# Iteration :67
# Total Loss 1.377279e+09.
# CPU times: user 22812500 µs, sys: 22812500000 ns, total: 22812501 µs
# Wall time: 12605324.27 µs
# Iteration :68
# Total Loss 1.347750e+09.
# CPU times: user 21015625 µs, sys: 21015625000 ns, total: 21015626 µs
# Wall time: 12449857.00 µs
# Iteration :69
# Total Loss 1.319705e+09.
# CPU times: user 21328125 µs, sys: 21328125000 ns, total: 21328126 µs
# Wall time: 12496533.16 µs
# Iteration :70
# Total Loss 1.292972e+09.
# CPU times: user 22250000 µs, sys: 22250000000 ns, total: 22250001 µs
# Wall time: 12559541.46 µs
# Iteration :71
# Total Loss 1.267611e+09.
# CPU times: user 22453125 µs, sys: 22453125000 ns, total: 22453126 µs
# Wall time: 12701112.03 µs
# Iteration :72
# Total Loss 1.243474e+09.
# CPU times: user 23468750 µs, sys: 23468750000 ns, total: 23468751 µs
# Wall time: 12613134.15 µs
# Iteration :73
# Total Loss 1.220416e+09.
# CPU times: user 22562500 µs, sys: 22562500000 ns, total: 22562501 µs
# Wall time: 12521647.69 µs
# Iteration :74
# Total Loss 1.198451e+09.
# CPU times: user 24218750 µs, sys: 24218750000 ns, total: 24218751 µs
# Wall time: 12848418.95 µs
# Iteration :75
# Total Loss 1.177421e+09.
# CPU times: user 20578125 µs, sys: 20578125000 ns, total: 20578126 µs
# Wall time: 12569115.64 µs
# Iteration :76
# Total Loss 1.157305e+09.
# CPU times: user 21937500 µs, sys: 21937500000 ns, total: 21937501 µs
# Wall time: 12567745.92 µs
# Iteration :77
# Total Loss 1.138067e+09.
# CPU times: user 21937500 µs, sys: 21937500000 ns, total: 21937501 µs
# Wall time: 12549827.81 µs
# Iteration :78
# Total Loss 1.119557e+09.
# CPU times: user 20984375 µs, sys: 20984375000 ns, total: 20984376 µs
# Wall time: 12442487.00 µs
# Iteration :79
# Total Loss 1.101773e+09.

# %%
# code to display the last 10 intermediate results
plt.figure(figsize=(12, 12))

# Adjust the range to display the last 10 images
for i in range(min(10, len(generated_images))):
    plt.subplot(4, 3, i + 1)
    display_image(generated_images[-10 + i])  # Access the last 10 images in the list
plt.show()

# %%
# plot best result
display_image(final_img)

# %%
# plot best result
display_image(final_img)
